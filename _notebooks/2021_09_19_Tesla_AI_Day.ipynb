# %% [markdown]
# # Tesla AI Day
# > Tesla's AI and Dojo Supercomputer
#
# - toc: true
# - badges: true
# - comments: true
# - sticky_rank: 1
# - author: Rayan Kejriwal
# - categories: [fastpages, jupyter]

# %% [markdown]
# > youtube: https://www.youtube.com/watch?v=j0z4FweCy4M&t=2975s

# %% [markdown]
# > Raw inputs which come into the stack and neural net processes into a vector space
# ![Capture1.JPG](data:image/jpeg;base64,...)
